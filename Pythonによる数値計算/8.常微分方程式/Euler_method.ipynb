# %%
import math

def f(t,x):
    return (t**2 + t + 1.0) - (2.0*t + 1.0) * x + x ** 2

def exact(t):
    return (t*math.exp(t)+t+1.0)/(math.exp(t)+1.0)

NM = 20
t = [0]*(NM+1)
x = [0]*(NM+1)
m = 20
h = 0.1
t[0] = 0.0
x[0] = 0.5 #初期条件

for n in range(m):
    t[n+1] = t[n] + h
    x[n+1] = x[n] + h*f(t[n],x[n])

print('{:^6}{:^15}{:^15}'.format('t(n)','calculated','exact'))
for n in range(m+1):
    print(f'{t[n]:6.2f}{x[n]:15.6f}{exact(t[n]):15.6f}')
# Out:
#  t(n)   calculated        exact
#   0.00       0.500000       0.500000
#   0.10       0.575000       0.575021
#   0.20       0.650062       0.650166
#   0.30       0.725312       0.725557
#   0.40       0.800870       0.801312
#   0.50       0.876852       0.877541
#   0.60       0.953369       0.954344
#   0.70       1.030519       1.031812
#   0.80       1.108391       1.110026
#   0.90       1.187063       1.189050
#   1.00       1.266597       1.268941
#   1.10       1.347045       1.349740
#   1.20       1.428443       1.431475
#   1.30       1.510818       1.514165
#   1.40       1.594180       1.597816
#   1.50       1.678533       1.682426
#   1.60       1.763867       1.767982
#   1.70       1.850165       1.854465
#   1.80       1.937404       1.941851
#   1.90       2.025552       2.030108
#   2.00       2.114573       2.119203

# %%
print('{:^6}{:^15}{:^15}{:^15}'.format('t(n)','calculated','exact','diff'))
for n in range(m+1):
    print(f'{t[n]:6.2f}{x[n]:15.6f}{exact(t[n]):15.6f}{x[n]-exact(t[n]):15.6f}')
# Out:
#  t(n)   calculated        exact          diff
#   0.00       0.500000       0.500000       0.000000
#   0.10       0.575000       0.575021      -0.000021
#   0.20       0.650062       0.650166      -0.000104
#   0.30       0.725312       0.725557      -0.000246
#   0.40       0.800870       0.801312      -0.000443
#   0.50       0.876852       0.877541      -0.000688
#   0.60       0.953369       0.954344      -0.000975
#   0.70       1.030519       1.031812      -0.001293
#   0.80       1.108391       1.110026      -0.001634
#   0.90       1.187063       1.189050      -0.001988
#   1.00       1.266597       1.268941      -0.002344
#   1.10       1.347045       1.349740      -0.002695
#   1.20       1.428443       1.431475      -0.003032
#   1.30       1.510818       1.514165      -0.003347
#   1.40       1.594180       1.597816      -0.003636
#   1.50       1.678533       1.682426      -0.003893
#   1.60       1.763867       1.767982      -0.004115
#   1.70       1.850165       1.854465      -0.004300
#   1.80       1.937404       1.941851      -0.004447
#   1.90       2.025552       2.030108      -0.004557
#   2.00       2.114573       2.119203      -0.004630
